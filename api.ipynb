# %%
# !pip install pillow
# Out:
# ...
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
# ...

# %%
# 17th September, 2025 
# Checkpoint for the gathering data with APIs. 

import requests
from PIL import Image

url = "https://api.nasa.gov/planetary/apod?api_key=7KghYMVYUsy465Bwv6y0vM9BYQ1fPDRGB2MUfV9V"
data = requests.get(url)
data = data.json()

# %%
data
# Out:
# {'copyright': '\nJ. De Winter,\nC. Humbert, \nC. Robert & \nV. Sabet;\nText: Ogetay Kayali \n(MTU) \n',
#  'date': '2025-09-17',
#  'explanation': "Can you spot famous celestial objects in this image?  18th-century astronomer Charles Messier cataloged only two of them: the bright Lagoon Nebula (M8) at the bottom, and the colorful Trifid Nebula (M20) at the upper right.  The one on the left that resembles a cat's paw is NGC 6559, and it is much fainter than the other two.  Even harder to spot are the thin blue filaments on the left, from supernova remnant (SNR G007.5-01.7).  Their glow comes from small amounts of glowing oxygen atoms that are so faint that it took over 17 hours of exposure with just one blue color to bring up. Framing this scene of stellar birth and death are two star clusters: the open cluster M21 just above Trifid, and the globular cluster NGC 6544 at lower left.",
#  'hdurl': 'https://apod.nasa.gov/apod/image/2509/SagNebs_DeWinter_4550.jpg',
# ...

# %%
# Display the image on yiour notebook 
image_url = data['url']

#download image content
content =requests.get(image_url).content

#save the image with disk
with open("image.jpg", "wb") as f:
    f.write(content)

#open the image    
Image.open("image.jpg")

#second question
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=960x1018>

# %% [markdown]
# ### Ateriods Neows

# %%
url2 = "https://api.nasa.gov/neo/rest/v1/feed?api_key=7KghYMVYUsy465Bwv6y0vM9BYQ1fPDRGB2MUfV9V"

# %%
data = requests.get(url2)
data = data.json()
data
# Out:
# {'links': {'next': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2025-09-24&end_date=2025-10-01&detailed=false&api_key=7KghYMVYUsy465Bwv6y0vM9BYQ1fPDRGB2MUfV9V',
#   'previous': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2025-09-10&end_date=2025-09-17&detailed=false&api_key=7KghYMVYUsy465Bwv6y0vM9BYQ1fPDRGB2MUfV9V',
#   'self': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2025-09-17&end_date=2025-09-24&detailed=false&api_key=7KghYMVYUsy465Bwv6y0vM9BYQ1fPDRGB2MUfV9V'},
#  'element_count': 98,
#  'near_earth_objects': {'2025-09-24': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3388408?api_key=7KghYMVYUsy465Bwv6y0vM9BYQ1fPDRGB2MUfV9V'},
#     'id': '3388408',
#     'neo_reference_id': '3388408',
#     'name': '(2007 TE71)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3388408',
#     'absolute_magnitude_h': 24.3,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0366906138,
# ...

# %% [markdown]
# ### Heading

# %% [markdown]
# Add bullet points
# - one
# - two
#
# Ordered List
# 1. One
# 2. Two
# 3. Three
#
# Bold Text
#
# **Boldened Text**
#
# Italics
#
# *Italiced*
#
# [Open](https://www.markdownguide.org/cheat-sheet/)
#
#
# ---
#
# `This is code block`
#
# ![This is an image of nasa](image.jpg)
#
# | Name | Age | Email | Class | Occupation |
# | ----|----| -----| ----| -----|
# |Moses | 24 |moses@gomycode.com | 5th grade | data sientist |
#
# ~~100 dollars~~
